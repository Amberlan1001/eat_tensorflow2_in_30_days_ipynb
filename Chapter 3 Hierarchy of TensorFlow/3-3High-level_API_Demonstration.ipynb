# %% [markdown]
# # 3-3 High-level API: Demonstration
#
# The examples below use high-level APIs in TensorFlow to implement a linear regression model.
#
# Typically, the high-level APIs are providing the class interfaces for `tf.keras.models`.
#
# There are three ways of modeling using APIs of Keras: sequential modeling using `Sequential()` function, arbitrary modeling using API functions, and customized modeling by inheriting base class `Model`.
#
# Here we are demonstrating using `Sequential()` function and customized modeling by inheriting base class `Model`, respectively.
#
#
# ### 1. Use `Sequential()` function to create a model sequencially (for the beginners)

# %%
import tensorflow as tf
from tensorflow.keras import models,layers,optimizers

# Number of samples
n = 800

# Generate testing dataset
X = tf.random.uniform([n,2],minval=-10,maxval=10) 
w0 = tf.constant([[2.0],[-1.0]])
b0 = tf.constant(3.0)

Y = X@w0 + b0 + tf.random.normal([n,1],mean = 0.0,stddev= 2.0)  # @ represents matrix multiplication; add Gaussian noise

# %%
tf.keras.backend.clear_session()

linear = models.Sequential()
linear.add(layers.Dense(1,input_shape =(2,)))
linear.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 3
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
### Training with fit method

linear.compile(optimizer="adam",loss="mse",metrics=["mae"])
linear.fit(X,Y,batch_size = 20,epochs = 200)  

tf.print("w = ",linear.layers[0].kernel)
# Out:
# Train on 800 samples
# Epoch 1/200
# 800/800 [==============================] - 0s 256us/sample - loss: 45.4000 - mae: 5.4908
# Epoch 2/200
# 800/800 [==============================] - 0s 38us/sample - loss: 41.9666 - mae: 5.2756
# Epoch 3/200
# 800/800 [==============================] - 0s 38us/sample - loss: 38.7465 - mae: 5.0686
# Epoch 4/200
# 800/800 [==============================] - 0s 34us/sample - loss: 35.8251 - mae: 4.8681
# Epoch 5/200
# 800/800 [==============================] - 0s 34us/sample - loss: 33.0641 - mae: 4.6745
# Epoch 6/200
# 800/800 [==============================] - 0s 38us/sample - loss: 30.5758 - mae: 4.4926
# Epoch 7/200
# 800/800 [==============================] - 0s 35us/sample - loss: 28.2652 - mae: 4.3157
# Epoch 8/200
# 800/800 [==============================] - 0s 35us/sample - loss: 26.1634 - mae: 4.1476
# Epoch 9/200
# 800/800 [==============================] - 0s 34us/sample - loss: 24.2196 - mae: 3.9884
# Epoch 10/200
# 800/800 [==============================] - 0s 39us/sample - loss: 22.4602 - mae: 3.8422
# Epoch 11/200
# 800/800 [==============================] - 0s 38us/sample - loss: 20.8793 - mae: 3.7056
# Epoch 12/200
# 800/800 [==============================] - 0s 39us/sample - loss: 19.4025 - mae: 3.5734
# Epoch 13/200
# 800/800 [==============================] - 0s 39us/sample - loss: 18.1003 - mae: 3.4484
# Epoch 14/200
# 800/800 [==============================] - 0s 38us/sample - loss: 16.8978 - mae: 3.3362
# Epoch 15/200
# 800/800 [==============================] - 0s 43us/sample - loss: 15.8403 - mae: 3.2295
# Epoch 16/200
# 800/800 [==============================] - 0s 52us/sample - loss: 14.8489 - mae: 3.1292
# Epoch 17/200
# 800/800 [==============================] - 0s 51us/sample - loss: 13.9815 - mae: 3.0380
# Epoch 18/200
# 800/800 [==============================] - 0s 48us/sample - loss: 13.1848 - mae: 2.9539
# Epoch 19/200
# 800/800 [==============================] - 0s 51us/sample - loss: 12.4808 - mae: 2.8760
# Epoch 20/200
# 800/800 [==============================] - 0s 52us/sample - loss: 11.8449 - mae: 2.8052
# Epoch 21/200
# 800/800 [==============================] - 0s 53us/sample - loss: 11.2641 - mae: 2.7369
# Epoch 22/200
# 800/800 [==============================] - 0s 50us/sample - loss: 10.7635 - mae: 2.6756
# Epoch 23/200
# 800/800 [==============================] - 0s 53us/sample - loss: 10.2921 - mae: 2.6182
# Epoch 24/200
# 800/800 [==============================] - 0s 52us/sample - loss: 9.8764 - mae: 2.5654
# Epoch 25/200
# 800/800 [==============================] - 0s 52us/sample - loss: 9.5053 - mae: 2.5161
# Epoch 26/200
# 800/800 [==============================] - 0s 53us/sample - loss: 9.1670 - mae: 2.4727
# Epoch 27/200
# 800/800 [==============================] - 0s 53us/sample - loss: 8.8610 - mae: 2.4329
# Epoch 28/200
# 800/800 [==============================] - 0s 54us/sample - loss: 8.5859 - mae: 2.3972
# Epoch 29/200
# 800/800 [==============================] - 0s 50us/sample - loss: 8.3357 - mae: 2.3609
# Epoch 30/200
# 800/800 [==============================] - 0s 48us/sample - loss: 8.1072 - mae: 2.3289
# Epoch 31/200
# 800/800 [==============================] - 0s 42us/sample - loss: 7.9036 - mae: 2.2969
# Epoch 32/200
# 800/800 [==============================] - 0s 39us/sample - loss: 7.7077 - mae: 2.2677
# Epoch 33/200
# 800/800 [==============================] - 0s 49us/sample - loss: 7.5329 - mae: 2.2407
# Epoch 34/200
# 800/800 [==============================] - 0s 54us/sample - loss: 7.3701 - mae: 2.2146
# Epoch 35/200
# 800/800 [==============================] - 0s 50us/sample - loss: 7.2179 - mae: 2.1901
# Epoch 36/200
# 800/800 [==============================] - 0s 64us/sample - loss: 7.0760 - mae: 2.1663
# Epoch 37/200
# 800/800 [==============================] - 0s 50us/sample - loss: 6.9437 - mae: 2.1442
# Epoch 38/200
# 800/800 [==============================] - 0s 46us/sample - loss: 6.8178 - mae: 2.1225
# Epoch 39/200
# 800/800 [==============================] - 0s 48us/sample - loss: 6.7003 - mae: 2.1017
# Epoch 40/200
# 800/800 [==============================] - 0s 45us/sample - loss: 6.5877 - mae: 2.0820
# Epoch 41/200
# 800/800 [==============================] - 0s 47us/sample - loss: 6.4821 - mae: 2.0628
# Epoch 42/200
# 800/800 [==============================] - 0s 52us/sample - loss: 6.3825 - mae: 2.0441
# Epoch 43/200
# 800/800 [==============================] - 0s 55us/sample - loss: 6.2827 - mae: 2.0265
# Epoch 44/200
# 800/800 [==============================] - 0s 59us/sample - loss: 6.1893 - mae: 2.0095
# Epoch 45/200
# 800/800 [==============================] - 0s 61us/sample - loss: 6.1026 - mae: 1.9938
# Epoch 46/200
# 800/800 [==============================] - 0s 59us/sample - loss: 6.0187 - mae: 1.9782
# Epoch 47/200
# 800/800 [==============================] - 0s 74us/sample - loss: 5.9344 - mae: 1.9632
# Epoch 48/200
# 800/800 [==============================] - 0s 58us/sample - loss: 5.8526 - mae: 1.9486
# Epoch 49/200
# 800/800 [==============================] - 0s 47us/sample - loss: 5.7764 - mae: 1.9350
# Epoch 50/200
# 800/800 [==============================] - 0s 45us/sample - loss: 5.7020 - mae: 1.9217
# Epoch 51/200
# 800/800 [==============================] - 0s 45us/sample - loss: 5.6317 - mae: 1.9096
# Epoch 52/200
# 800/800 [==============================] - 0s 44us/sample - loss: 5.5630 - mae: 1.8966
# Epoch 53/200
# 800/800 [==============================] - 0s 35us/sample - loss: 5.4940 - mae: 1.8849
# Epoch 54/200
# 800/800 [==============================] - 0s 30us/sample - loss: 5.4278 - mae: 1.8728
# Epoch 55/200
# 800/800 [==============================] - 0s 44us/sample - loss: 5.3657 - mae: 1.8619
# Epoch 56/200
# 800/800 [==============================] - 0s 36us/sample - loss: 5.3059 - mae: 1.8509
# Epoch 57/200
# 800/800 [==============================] - 0s 47us/sample - loss: 5.2466 - mae: 1.8396
# Epoch 58/200
# 800/800 [==============================] - 0s 51us/sample - loss: 5.1897 - mae: 1.8294
# Epoch 59/200
# 800/800 [==============================] - 0s 46us/sample - loss: 5.1358 - mae: 1.8199
# Epoch 60/200
# 800/800 [==============================] - 0s 41us/sample - loss: 5.0823 - mae: 1.8102
# Epoch 61/200
# 800/800 [==============================] - 0s 52us/sample - loss: 5.0324 - mae: 1.8010
# Epoch 62/200
# 800/800 [==============================] - 0s 49us/sample - loss: 4.9827 - mae: 1.7925
# Epoch 63/200
# 800/800 [==============================] - 0s 43us/sample - loss: 4.9370 - mae: 1.7839
# Epoch 64/200
# 800/800 [==============================] - 0s 42us/sample - loss: 4.8905 - mae: 1.7758
# Epoch 65/200
# 800/800 [==============================] - 0s 42us/sample - loss: 4.8464 - mae: 1.7675
# Epoch 66/200
# 800/800 [==============================] - 0s 42us/sample - loss: 4.8025 - mae: 1.7593
# Epoch 67/200
# 800/800 [==============================] - 0s 42us/sample - loss: 4.7627 - mae: 1.7523
# Epoch 68/200
# 800/800 [==============================] - 0s 40us/sample - loss: 4.7247 - mae: 1.7452
# Epoch 69/200
# 800/800 [==============================] - 0s 42us/sample - loss: 4.6850 - mae: 1.7378
# Epoch 70/200
# 800/800 [==============================] - 0s 39us/sample - loss: 4.6503 - mae: 1.7315
# Epoch 71/200
# 800/800 [==============================] - 0s 40us/sample - loss: 4.6136 - mae: 1.7247
# Epoch 72/200
# 800/800 [==============================] - 0s 37us/sample - loss: 4.5818 - mae: 1.7188
# Epoch 73/200
# 800/800 [==============================] - 0s 36us/sample - loss: 4.5496 - mae: 1.7126
# Epoch 74/200
# 800/800 [==============================] - 0s 35us/sample - loss: 4.5190 - mae: 1.7068
# Epoch 75/200
# 800/800 [==============================] - 0s 35us/sample - loss: 4.4897 - mae: 1.7016
# Epoch 76/200
# 800/800 [==============================] - 0s 33us/sample - loss: 4.4624 - mae: 1.6963
# Epoch 77/200
# 800/800 [==============================] - 0s 34us/sample - loss: 4.4350 - mae: 1.6921
# Epoch 78/200
# 800/800 [==============================] - 0s 34us/sample - loss: 4.4107 - mae: 1.6878
# Epoch 79/200
# 800/800 [==============================] - 0s 35us/sample - loss: 4.3839 - mae: 1.6828
# Epoch 80/200
# 800/800 [==============================] - 0s 36us/sample - loss: 4.3602 - mae: 1.6786
# Epoch 81/200
# 800/800 [==============================] - 0s 37us/sample - loss: 4.3393 - mae: 1.6756
# Epoch 82/200
# 800/800 [==============================] - 0s 39us/sample - loss: 4.3183 - mae: 1.6719
# Epoch 83/200
# 800/800 [==============================] - 0s 39us/sample - loss: 4.2970 - mae: 1.6685
# Epoch 84/200
# 800/800 [==============================] - 0s 38us/sample - loss: 4.2778 - mae: 1.6649
# Epoch 85/200
# 800/800 [==============================] - 0s 38us/sample - loss: 4.2592 - mae: 1.6614
# Epoch 86/200
# 800/800 [==============================] - 0s 39us/sample - loss: 4.2421 - mae: 1.6584
# Epoch 87/200
# 800/800 [==============================] - 0s 39us/sample - loss: 4.2279 - mae: 1.6561
# Epoch 88/200
# 800/800 [==============================] - 0s 34us/sample - loss: 4.2110 - mae: 1.6528
# Epoch 89/200
# 800/800 [==============================] - 0s 29us/sample - loss: 4.1959 - mae: 1.6501
# Epoch 90/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.1818 - mae: 1.6477
# Epoch 91/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.1692 - mae: 1.6458
# Epoch 92/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.1558 - mae: 1.6431
# Epoch 93/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.1453 - mae: 1.6414
# Epoch 94/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.1347 - mae: 1.6398
# Epoch 95/200
# 800/800 [==============================] - 0s 31us/sample - loss: 4.1228 - mae: 1.6374
# Epoch 96/200
# 800/800 [==============================] - 0s 34us/sample - loss: 4.1133 - mae: 1.6361
# Epoch 97/200
# 800/800 [==============================] - 0s 35us/sample - loss: 4.1052 - mae: 1.6348
# Epoch 98/200
# 800/800 [==============================] - 0s 34us/sample - loss: 4.0968 - mae: 1.6333
# Epoch 99/200
# 800/800 [==============================] - 0s 33us/sample - loss: 4.0891 - mae: 1.6319
# Epoch 100/200
# 800/800 [==============================] - 0s 32us/sample - loss: 4.0810 - mae: 1.6305
# Epoch 101/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.0742 - mae: 1.6293
# Epoch 102/200
# 800/800 [==============================] - 0s 29us/sample - loss: 4.0678 - mae: 1.6284
# Epoch 103/200
# 800/800 [==============================] - 0s 29us/sample - loss: 4.0636 - mae: 1.6279
# Epoch 104/200
# 800/800 [==============================] - 0s 31us/sample - loss: 4.0570 - mae: 1.6263
# Epoch 105/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.0527 - mae: 1.6264
# Epoch 106/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.0466 - mae: 1.6245
# Epoch 107/200
# 800/800 [==============================] - 0s 31us/sample - loss: 4.0401 - mae: 1.6236
# Epoch 108/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.0362 - mae: 1.6232
# Epoch 109/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.0331 - mae: 1.6230
# Epoch 110/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.0300 - mae: 1.6223
# Epoch 111/200
# 800/800 [==============================] - 0s 31us/sample - loss: 4.0280 - mae: 1.6222
# Epoch 112/200
# 800/800 [==============================] - 0s 32us/sample - loss: 4.0226 - mae: 1.6213
# Epoch 113/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.0205 - mae: 1.6208
# Epoch 114/200
# 800/800 [==============================] - 0s 33us/sample - loss: 4.0194 - mae: 1.6210
# Epoch 115/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.0152 - mae: 1.6202
# Epoch 116/200
# 800/800 [==============================] - 0s 31us/sample - loss: 4.0138 - mae: 1.6204
# Epoch 117/200
# 800/800 [==============================] - 0s 34us/sample - loss: 4.0127 - mae: 1.6199
# Epoch 118/200
# 800/800 [==============================] - 0s 44us/sample - loss: 4.0095 - mae: 1.6197
# Epoch 119/200
# 800/800 [==============================] - 0s 41us/sample - loss: 4.0075 - mae: 1.6194
# Epoch 120/200
# 800/800 [==============================] - 0s 39us/sample - loss: 4.0047 - mae: 1.6188
# Epoch 121/200
# 800/800 [==============================] - 0s 35us/sample - loss: 4.0050 - mae: 1.6187
# Epoch 122/200
# 800/800 [==============================] - 0s 34us/sample - loss: 4.0027 - mae: 1.6188
# Epoch 123/200
# 800/800 [==============================] - 0s 35us/sample - loss: 4.0018 - mae: 1.6186
# Epoch 124/200
# 800/800 [==============================] - 0s 34us/sample - loss: 4.0016 - mae: 1.6191
# Epoch 125/200
# 800/800 [==============================] - 0s 31us/sample - loss: 4.0015 - mae: 1.6191
# Epoch 126/200
# 800/800 [==============================] - 0s 30us/sample - loss: 4.0007 - mae: 1.6188
# Epoch 127/200
# 800/800 [==============================] - 0s 32us/sample - loss: 4.0014 - mae: 1.6191
# Epoch 128/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9998 - mae: 1.6187
# Epoch 129/200
# 800/800 [==============================] - 0s 33us/sample - loss: 3.9988 - mae: 1.6185
# Epoch 130/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9990 - mae: 1.6190
# Epoch 131/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9959 - mae: 1.6182
# Epoch 132/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9968 - mae: 1.6179
# Epoch 133/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9955 - mae: 1.6175
# Epoch 134/200
# 800/800 [==============================] - 0s 29us/sample - loss: 3.9977 - mae: 1.6191
# Epoch 135/200
# 800/800 [==============================] - 0s 33us/sample - loss: 3.9964 - mae: 1.6178
# Epoch 136/200
# 800/800 [==============================] - 0s 36us/sample - loss: 3.9980 - mae: 1.6190
# Epoch 137/200
# 800/800 [==============================] - 0s 36us/sample - loss: 3.9952 - mae: 1.6183
# Epoch 138/200
# 800/800 [==============================] - 0s 34us/sample - loss: 3.9942 - mae: 1.6182
# Epoch 139/200
# 800/800 [==============================] - 0s 32us/sample - loss: 3.9934 - mae: 1.6181
# Epoch 140/200
# 800/800 [==============================] - 0s 29us/sample - loss: 3.9986 - mae: 1.6198
# Epoch 141/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9964 - mae: 1.6182
# Epoch 142/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9935 - mae: 1.6178
# Epoch 143/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9934 - mae: 1.6179
# Epoch 144/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9944 - mae: 1.6183
# Epoch 145/200
# 800/800 [==============================] - 0s 32us/sample - loss: 3.9946 - mae: 1.6182
# Epoch 146/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9937 - mae: 1.6181
# Epoch 147/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9942 - mae: 1.6181
# Epoch 148/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9933 - mae: 1.6182
# Epoch 149/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9940 - mae: 1.6182
# Epoch 150/200
# 800/800 [==============================] - 0s 28us/sample - loss: 3.9932 - mae: 1.6179
# Epoch 151/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9928 - mae: 1.6182
# Epoch 152/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9942 - mae: 1.6183
# Epoch 153/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9935 - mae: 1.6184
# Epoch 154/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9962 - mae: 1.6192
# Epoch 155/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9936 - mae: 1.6184
# Epoch 156/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9944 - mae: 1.6182
# Epoch 157/200
# 800/800 [==============================] - 0s 29us/sample - loss: 3.9940 - mae: 1.6188
# Epoch 158/200
# 800/800 [==============================] - 0s 29us/sample - loss: 3.9931 - mae: 1.6188
# Epoch 159/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9929 - mae: 1.6183
# Epoch 160/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9942 - mae: 1.6189
# Epoch 161/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9950 - mae: 1.6191
# Epoch 162/200
# 800/800 [==============================] - 0s 32us/sample - loss: 3.9957 - mae: 1.6190
# Epoch 163/200
# 800/800 [==============================] - 0s 33us/sample - loss: 3.9942 - mae: 1.6185
# Epoch 164/200
# 800/800 [==============================] - 0s 34us/sample - loss: 3.9939 - mae: 1.6181
# Epoch 165/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9931 - mae: 1.6187
# Epoch 166/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9953 - mae: 1.6190
# Epoch 167/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9955 - mae: 1.6192
# Epoch 168/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9951 - mae: 1.6183
# Epoch 169/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9948 - mae: 1.6189
# Epoch 170/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9937 - mae: 1.6183
# Epoch 171/200
# 800/800 [==============================] - 0s 29us/sample - loss: 3.9954 - mae: 1.6189
# Epoch 172/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9947 - mae: 1.6187
# Epoch 173/200
# 800/800 [==============================] - 0s 29us/sample - loss: 3.9938 - mae: 1.6186
# Epoch 174/200
# 800/800 [==============================] - 0s 29us/sample - loss: 3.9958 - mae: 1.6191
# Epoch 175/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9971 - mae: 1.6190
# Epoch 176/200
# 800/800 [==============================] - 0s 35us/sample - loss: 3.9929 - mae: 1.6184
# Epoch 177/200
# 800/800 [==============================] - 0s 32us/sample - loss: 3.9952 - mae: 1.6189
# Epoch 178/200
# 800/800 [==============================] - 0s 32us/sample - loss: 3.9962 - mae: 1.6195
# Epoch 179/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9924 - mae: 1.6182
# Epoch 180/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9956 - mae: 1.6192
# Epoch 181/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9933 - mae: 1.6182
# Epoch 182/200
# 800/800 [==============================] - 0s 33us/sample - loss: 3.9939 - mae: 1.6186
# Epoch 183/200
# 800/800 [==============================] - 0s 33us/sample - loss: 3.9934 - mae: 1.6185
# Epoch 184/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9950 - mae: 1.6183
# Epoch 185/200
# 800/800 [==============================] - 0s 31us/sample - loss: 3.9959 - mae: 1.6190
# Epoch 186/200
# 800/800 [==============================] - 0s 30us/sample - loss: 3.9982 - mae: 1.6190
# Epoch 187/200
# 800/800 [==============================] - 0s 29us/sample - loss: 3.9939 - mae: 1.6187
# Epoch 188/200
# 800/800 [==============================] - 0s 33us/sample - loss: 3.9937 - mae: 1.6191
# Epoch 189/200
# 800/800 [==============================] - 0s 38us/sample - loss: 3.9961 - mae: 1.6192
# Epoch 190/200
# 800/800 [==============================] - 0s 39us/sample - loss: 3.9939 - mae: 1.6190
# Epoch 191/200
# 800/800 [==============================] - 0s 41us/sample - loss: 3.9948 - mae: 1.6186
# Epoch 192/200
# 800/800 [==============================] - 0s 42us/sample - loss: 3.9960 - mae: 1.6186
# Epoch 193/200
# 800/800 [==============================] - 0s 47us/sample - loss: 3.9957 - mae: 1.6188
# Epoch 194/200
# 800/800 [==============================] - 0s 43us/sample - loss: 3.9945 - mae: 1.6193
# Epoch 195/200
# 800/800 [==============================] - 0s 40us/sample - loss: 3.9946 - mae: 1.6184
# Epoch 196/200
# 800/800 [==============================] - 0s 39us/sample - loss: 3.9934 - mae: 1.6184
# Epoch 197/200
# 800/800 [==============================] - 0s 39us/sample - loss: 3.9927 - mae: 1.6184
# Epoch 198/200
# 800/800 [==============================] - 0s 38us/sample - loss: 3.9931 - mae: 1.6185
# Epoch 199/200
# 800/800 [==============================] - 0s 36us/sample - loss: 3.9936 - mae: 1.6190
# Epoch 200/200
# 800/800 [==============================] - 0s 36us/sample - loss: 3.9940 - mae: 1.6184
# w =  [[1.99828291]
#  [-1.02342927]]

# %% [markdown]
# ### 2. Customized modeling by inheriting base class `Model` (for the experts)

# %%
import tensorflow as tf
from tensorflow.keras import models,layers,optimizers,losses,metrics


# Print time stamps
@tf.function
def printbar():
    ts = tf.timestamp()
    today_ts = ts%(24*60*60)

    hour = tf.cast(today_ts//3600+8,tf.int32)%tf.constant(24)
    minite = tf.cast((today_ts%3600)//60,tf.int32)
    second = tf.cast(tf.floor(today_ts%60),tf.int32)
    
    def timeformat(m):
        if tf.strings.length(tf.strings.format("{}",m))==1:
            return(tf.strings.format("0{}",m))
        else:
            return(tf.strings.format("{}",m))
    
    timestring = tf.strings.join([timeformat(hour),timeformat(minite),
                timeformat(second)],separator = ":")
    tf.print("=========="*8,end = "")
    tf.print(timestring)

# %%
# Number of samples
n = 800

# Generate testing dataset
X = tf.random.uniform([n,2],minval=-10,maxval=10) 
w0 = tf.constant([[2.0],[-1.0]])
b0 = tf.constant(3.0)

Y = X@w0 + b0 + tf.random.normal([n,1],mean = 0.0,stddev= 2.0)  # @ represents matrix multiplication; add Gaussian noise

ds_train = tf.data.Dataset.from_tensor_slices((X[0:n*3//4,:],Y[0:n*3//4,:])) \
     .shuffle(buffer_size = 1000).batch(20) \
     .prefetch(tf.data.experimental.AUTOTUNE) \
     .cache()

ds_valid = tf.data.Dataset.from_tensor_slices((X[n*3//4:,:],Y[n*3//4:,:])) \
     .shuffle(buffer_size = 1000).batch(20) \
     .prefetch(tf.data.experimental.AUTOTUNE) \
     .cache()

# %%
tf.keras.backend.clear_session()

class MyModel(models.Model):
    def __init__(self):
        super(MyModel, self).__init__()
        
    def build(self,input_shape):
        self.dense1 = layers.Dense(1)   
        super(MyModel,self).build(input_shape)
    
    def call(self, x):
        y = self.dense1(x)
        return(y)

model = MyModel()
model.build(input_shape =(None,2))
model.summary()
# Out:
# Model: "my_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  3
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
### Customizing training loop (tutorial for the experts)


optimizer = optimizers.Adam()
loss_func = losses.MeanSquaredError()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_metric = tf.keras.metrics.MeanAbsoluteError(name='train_mae')

valid_loss = tf.keras.metrics.Mean(name='valid_loss')
valid_metric = tf.keras.metrics.MeanAbsoluteError(name='valid_mae')


@tf.function
def train_step(model, features, labels):
    with tf.GradientTape() as tape:
        predictions = model(features)
        loss = loss_func(labels, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    train_loss.update_state(loss)
    train_metric.update_state(labels, predictions)

@tf.function
def valid_step(model, features, labels):
    predictions = model(features)
    batch_loss = loss_func(labels, predictions)
    valid_loss.update_state(batch_loss)
    valid_metric.update_state(labels, predictions)
    

@tf.function
def train_model(model,ds_train,ds_valid,epochs):
    for epoch in tf.range(1,epochs+1):
        for features, labels in ds_train:
            train_step(model,features,labels)

        for features, labels in ds_valid:
            valid_step(model,features,labels)

        logs = 'Epoch={},Loss:{},MAE:{},Valid Loss:{},Valid MAE:{}'
        
        if  epoch%100 ==0:
            printbar()
            tf.print(tf.strings.format(logs,
            (epoch,train_loss.result(),train_metric.result(),valid_loss.result(),valid_metric.result())))
            tf.print("w=",model.layers[0].kernel)
            tf.print("b=",model.layers[0].bias)
            tf.print("")
        
        train_loss.reset_states()
        valid_loss.reset_states()
        train_metric.reset_states()
        valid_metric.reset_states()

train_model(model,ds_train,ds_valid,400)
# Out:
# ================================================================================16:31:13
# Epoch=100,Loss:100.84388,MAE:7.94069195,Valid Loss:97.2003555,Valid MAE:7.996737
# w= [[1.41411638]
#  [-1.02094865]]
# b= [1.80114055]
#
# ================================================================================16:31:20
# Epoch=200,Loss:53.1216393,MAE:4.89377928,Valid Loss:51.0633812,Valid MAE:4.90537262
# w= [[1.9891212]
#  [-1.01212275]]
# b= [2.89756393]
#
# ================================================================================16:31:27
# Epoch=300,Loss:36.6023254,MAE:3.76881385,Valid Loss:35.1779671,Valid MAE:3.78182697
# w= [[1.9923569]
#  [-1.01145089]]
# b= [2.98073745]
#
# ================================================================================16:31:34
# Epoch=400,Loss:28.3633537,MAE:3.20791626,Valid Loss:27.2563629,Valid MAE:3.22140265
# w= [[1.99243522]
#  [-1.01144516]]
# b= [2.98090124]
