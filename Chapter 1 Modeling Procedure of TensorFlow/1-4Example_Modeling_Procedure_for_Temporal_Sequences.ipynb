# %% [markdown]
# # 1-4 Example: Modeling Procedure for Temporal Sequences
#
#
# The COVID-19 has been lasting for over three months (Note from the translator: until April, 2020) in China and significantly affected the ordinary life.
#
# The impacts could be on the incomes, emotions, psychologies, and weights.
#
# So how long this pandemic is going to last, and when will we be free again?
#
# This example is about predicting the time of COVID-19 termination in China using RNN model established by TensorFlow 2.

# %% [markdown]
# ### 1. Data Preparation
#
# <!-- #region -->
#
#
# The dataset is extracted from "tushare". The details of the data acquisition is [here (in Chinese)](https://zhuanlan.zhihu.com/p/109556102).
#
# ![](./data/1-4-新增人数.png)
#
# <!-- #endregion -->

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf 
from tensorflow.keras import models,layers,losses,metrics,callbacks

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

df = pd.read_csv("./data/covid-19.csv",sep = "\t")
df.plot(x = "date",y = ["confirmed_num","cured_num","dead_num"],figsize=(10,6))
plt.xticks(rotation=60)
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.]),
#  <a list of 7 Text xticklabel objects>)

# %%
dfdata = df.set_index("date")
dfdiff = dfdata.diff(periods=1).dropna()
dfdiff = dfdiff.reset_index("date")

dfdiff.plot(x = "date",y = ["confirmed_num","cured_num","dead_num"],figsize=(10,6))
plt.xticks(rotation=60)
dfdiff = dfdiff.drop("date",axis = 1).astype("float32")

# %%
#Use the data of an eight-day window priorier of the date we are investigating as input for prediction
WINDOW_SIZE = 8

def batch_dataset(dataset):
    dataset_batched = dataset.batch(WINDOW_SIZE,drop_remainder=True)
    return dataset_batched

ds_data = tf.data.Dataset.from_tensor_slices(tf.constant(dfdiff.values,dtype = tf.float32)) \
   .window(WINDOW_SIZE,shift=1).flat_map(batch_dataset)

ds_label = tf.data.Dataset.from_tensor_slices(
    tf.constant(dfdiff.values[WINDOW_SIZE:],dtype = tf.float32))

#We can put all data into one batch to enhance the performance since the data volume is small.
ds_train = tf.data.Dataset.zip((ds_data,ds_label)).batch(38).cache()

# %% [markdown]
# ### 2. Model Definition
#
#
# Usually there are three ways of modeling using APIs of Keras: sequential modeling using Sequential() function, arbitrary modeling using API functions, and customized modeling by inheriting base class Model.
#
# Here we use API functions for modeling.

# %%
#We design the following block since the daily increment of confirmed, discharged and deceased cases are equal or larger than zero.
class Block(layers.Layer):
    def __init__(self, **kwargs):
        super(Block, self).__init__(**kwargs)
    
    def call(self, x_input,x):
        x_out = tf.maximum((1+x)*x_input[:,-1,:],0.0)
        return x_out
    
    def get_config(self):  
        config = super(Block, self).get_config()
        return config

# %%
tf.keras.backend.clear_session()
x_input = layers.Input(shape = (None,3),dtype = tf.float32)
x = layers.LSTM(3,return_sequences = True,input_shape=(None,3))(x_input)
x = layers.LSTM(3,return_sequences = True,input_shape=(None,3))(x)
x = layers.LSTM(3,return_sequences = True,input_shape=(None,3))(x)
x = layers.LSTM(3,input_shape=(None,3))(x)
x = layers.Dense(3)(x)

#We design the following block since the daily increment of confirmed, discharged and deseased cases are equal or larger than zero.
#x = tf.maximum((1+x)*x_input[:,-1,:],0.0)
x = Block()(x_input,x)
model = models.Model(inputs = [x_input],outputs = [x])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, 3)]         0
# _________________________________________________________________
# lstm (LSTM)                  (None, None, 3)           84
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 3)           84
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 3)           84
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 3)                 84
# _________________________________________________________________
# dense (Dense)                (None, 3)                 12
# _________________________________________________________________
# block (Block)                (None, 3)                 0
# =================================================================
# Total params: 348
# Trainable params: 348
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3. Model Training
#
# There are three usual ways for model training: use internal function fit, use internal function train_on_batch, and customized training loop. Here we use the simplist way: using internal function fit.
#
# Note: The parameter adjustment of RNN is more difficult comparing to other types of neural network. We need to try various learning rate to achieve a satisfying result.

# %%
#Customized loss function, consider the ratio between square error and the prediction
class MSPE(losses.Loss):
    def call(self,y_true,y_pred):
        err_percent = (y_true - y_pred)**2/(tf.maximum(y_true**2,1e-7))
        mean_err_percent = tf.reduce_mean(err_percent)
        return mean_err_percent
    
    def get_config(self):
        config = super(MSPE, self).get_config()
        return config

# %%
import datetime

optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=optimizer,loss=MSPE(name = "MSPE"))

logdir = "./data/keras_model/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

tb_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
#Half the learning rate if loss is not improved after 100 epoches
lr_callback = tf.keras.callbacks.ReduceLROnPlateau(monitor="loss",factor = 0.5, patience = 100)
#Stop training when loss is not improved after 200 epoches
stop_callback = tf.keras.callbacks.EarlyStopping(monitor = "loss", patience= 200)
callbacks_list = [tb_callback,lr_callback,stop_callback]

history = model.fit(ds_train,epochs=500,callbacks = callbacks_list)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 4s 4s/step - loss: 3.5449
# Epoch 2/500
# 1/1 [==============================] - 0s 40ms/step - loss: 3.3331
# Epoch 3/500
# 1/1 [==============================] - 0s 31ms/step - loss: 3.1533
# Epoch 4/500
# 1/1 [==============================] - 0s 30ms/step - loss: 2.9889
# Epoch 5/500
# 1/1 [==============================] - 0s 33ms/step - loss: 2.8306
# Epoch 6/500
# 1/1 [==============================] - 0s 34ms/step - loss: 2.6721
# Epoch 7/500
# 1/1 [==============================] - 0s 33ms/step - loss: 2.5109
# Epoch 8/500
# 1/1 [==============================] - 0s 32ms/step - loss: 2.3436
# Epoch 9/500
# 1/1 [==============================] - 0s 33ms/step - loss: 2.1688
# Epoch 10/500
# 1/1 [==============================] - 0s 34ms/step - loss: 1.9856
# Epoch 11/500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7939
# Epoch 12/500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.5946
# Epoch 13/500
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3886
# Epoch 14/500
# 1/1 [==============================] - 0s 40ms/step - loss: 1.1812
# Epoch 15/500
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0167
# Epoch 16/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.8336
# Epoch 17/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6652
# Epoch 18/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5282
# Epoch 19/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4350
# Epoch 20/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3953
# Epoch 21/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4087
# Epoch 22/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4166
# Epoch 23/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4261
# Epoch 24/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4178
# Epoch 25/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4125
# Epoch 26/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4082
# Epoch 27/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4049
# Epoch 28/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4024
# Epoch 29/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3983
# Epoch 30/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3914
# Epoch 31/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4708
# Epoch 32/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4624
# Epoch 33/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4360
# Epoch 34/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4155
# Epoch 35/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4337
# Epoch 36/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4259
# Epoch 37/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4387
# Epoch 38/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4493
# Epoch 39/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4527
# Epoch 40/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4524
# Epoch 41/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4508
# Epoch 42/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4490
# Epoch 43/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4473
# Epoch 44/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4456
# Epoch 45/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4448
# Epoch 46/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4430
# Epoch 47/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4421
# Epoch 48/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4415
# Epoch 49/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4412
# Epoch 50/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4412
# Epoch 51/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4414
# Epoch 52/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4416
# Epoch 53/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4420
# Epoch 54/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4423
# Epoch 55/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4426
# Epoch 56/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4428
# Epoch 57/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4428
# Epoch 58/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4428
# Epoch 59/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4426
# Epoch 60/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4424
# Epoch 61/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4421
# Epoch 62/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4418
# Epoch 63/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4415
# Epoch 64/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4413
# Epoch 65/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4410
# Epoch 66/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4409
# Epoch 67/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4407
# Epoch 68/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4407
# Epoch 69/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4406
# Epoch 70/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4406
# Epoch 71/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4406
# Epoch 72/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4406
# Epoch 73/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4406
# Epoch 74/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4406
# Epoch 75/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4406
# Epoch 76/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4406
# Epoch 77/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4406
# Epoch 78/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4405
# Epoch 79/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4404
# Epoch 80/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4403
# Epoch 81/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4403
# Epoch 82/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4402
# Epoch 83/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4401
# Epoch 84/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4400
# Epoch 85/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4400
# Epoch 86/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4400
# Epoch 87/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4399
# Epoch 88/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4399
# Epoch 89/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4399
# Epoch 90/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4398
# Epoch 91/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4398
# Epoch 92/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4398
# Epoch 93/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4397
# Epoch 94/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4397
# Epoch 95/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4396
# Epoch 96/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4396
# Epoch 97/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4396
# Epoch 98/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4395
# Epoch 99/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4395
# Epoch 100/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4394
# Epoch 101/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4394
# Epoch 102/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4393
# Epoch 103/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4393
# Epoch 104/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4393
# Epoch 105/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4392
# Epoch 106/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4392
# Epoch 107/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4392
# Epoch 108/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4391
# Epoch 109/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4391
# Epoch 110/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4391
# Epoch 111/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4390
# Epoch 112/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4390
# Epoch 113/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4390
# Epoch 114/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4389
# Epoch 115/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4389
# Epoch 116/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4389
# Epoch 117/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4388
# Epoch 118/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4388
# Epoch 119/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4388
# Epoch 120/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4387
# Epoch 121/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4387
# Epoch 122/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4387
# Epoch 123/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4386
# Epoch 124/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4386
# Epoch 125/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4386
# Epoch 126/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4386
# Epoch 127/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4385
# Epoch 128/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4385
# Epoch 129/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4385
# Epoch 130/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4384
# Epoch 131/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4384
# Epoch 132/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4384
# Epoch 133/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4384
# Epoch 134/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4384
# Epoch 135/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4384
# Epoch 136/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4383
# Epoch 137/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4375
# Epoch 138/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4359
# Epoch 139/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4336
# Epoch 140/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4308
# Epoch 141/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4246
# Epoch 142/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4147
# Epoch 143/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4102
# Epoch 144/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4124
# Epoch 145/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4176
# Epoch 146/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4215
# Epoch 147/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4215
# Epoch 148/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4179
# Epoch 149/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4133
# Epoch 150/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4100
# Epoch 151/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4097
# Epoch 152/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4116
# Epoch 153/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4139
# Epoch 154/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4148
# Epoch 155/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4136
# Epoch 156/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4114
# Epoch 157/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4094
# Epoch 158/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4087
# Epoch 159/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4093
# Epoch 160/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4103
# Epoch 161/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4109
# Epoch 162/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4106
# Epoch 163/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4096
# Epoch 164/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4085
# Epoch 165/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4079
# Epoch 166/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4079
# Epoch 167/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4083
# Epoch 168/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4086
# Epoch 169/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4085
# Epoch 170/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4079
# Epoch 171/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4073
# Epoch 172/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4068
# Epoch 173/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4067
# Epoch 174/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4067
# Epoch 175/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4068
# Epoch 176/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4067
# Epoch 177/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4063
# Epoch 178/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4058
# Epoch 179/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4055
# Epoch 180/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4053
# Epoch 181/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4053
# Epoch 182/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4052
# Epoch 183/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4050
# Epoch 184/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4047
# Epoch 185/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4043
# Epoch 186/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4040
# Epoch 187/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4039
# Epoch 188/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4037
# Epoch 189/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4035
# Epoch 190/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4032
# Epoch 191/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4029
# Epoch 192/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4026
# Epoch 193/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4024
# Epoch 194/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4022
# Epoch 195/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4019
# Epoch 196/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4017
# Epoch 197/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4013
# Epoch 198/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4010
# Epoch 199/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4007
# Epoch 200/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4005
# Epoch 201/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4002
# Epoch 202/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3999
# Epoch 203/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3996
# Epoch 204/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3992
# Epoch 205/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3989
# Epoch 206/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3986
# Epoch 207/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3982
# Epoch 208/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3979
# Epoch 209/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3975
# Epoch 210/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3972
# Epoch 211/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3968
# Epoch 212/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3964
# Epoch 213/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3960
# Epoch 214/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3956
# Epoch 215/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3952
# Epoch 216/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3948
# Epoch 217/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3944
# Epoch 218/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3940
# Epoch 219/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3935
# Epoch 220/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3931
# Epoch 221/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3926
# Epoch 222/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3922
# Epoch 223/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3917
# Epoch 224/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3912
# Epoch 225/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3907
# Epoch 226/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3902
# Epoch 227/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3897
# Epoch 228/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3892
# Epoch 229/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3886
# Epoch 230/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3881
# Epoch 231/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3875
# Epoch 232/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3869
# Epoch 233/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3864
# Epoch 234/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3858
# Epoch 235/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3852
# Epoch 236/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3845
# Epoch 237/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3839
# Epoch 238/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3833
# Epoch 239/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3826
# Epoch 240/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3819
# Epoch 241/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3813
# Epoch 242/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3806
# Epoch 243/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3799
# Epoch 244/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3791
# Epoch 245/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3784
# Epoch 246/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3777
# Epoch 247/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3769
# Epoch 248/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3762
# Epoch 249/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3754
# Epoch 250/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3746
# Epoch 251/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3738
# Epoch 252/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3730
# Epoch 253/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3722
# Epoch 254/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3713
# Epoch 255/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3705
# Epoch 256/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3696
# Epoch 257/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3688
# Epoch 258/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3679
# Epoch 259/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3670
# Epoch 260/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3662
# Epoch 261/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3653
# Epoch 262/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3644
# Epoch 263/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3635
# Epoch 264/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3626
# Epoch 265/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3617
# Epoch 266/500
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3608
# Epoch 267/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3598
# Epoch 268/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3589
# Epoch 269/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3580
# Epoch 270/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3571
# Epoch 271/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3562
# Epoch 272/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3553
# Epoch 273/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3544
# Epoch 274/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3535
# Epoch 275/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3526
# Epoch 276/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3517
# Epoch 277/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3508
# Epoch 278/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3499
# Epoch 279/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3490
# Epoch 280/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3481
# Epoch 281/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3473
# Epoch 282/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3464
# Epoch 283/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3456
# Epoch 284/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3448
# Epoch 285/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3439
# Epoch 286/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3431
# Epoch 287/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3423
# Epoch 288/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3416
# Epoch 289/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3408
# Epoch 290/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3400
# Epoch 291/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3393
# Epoch 292/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3386
# Epoch 293/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3379
# Epoch 294/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3372
# Epoch 295/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3365
# Epoch 296/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3358
# Epoch 297/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3352
# Epoch 298/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3345
# Epoch 299/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3339
# Epoch 300/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3333
# Epoch 301/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3327
# Epoch 302/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3321
# Epoch 303/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3316
# Epoch 304/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3310
# Epoch 305/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3305
# Epoch 306/500
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3300
# Epoch 307/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3295
# Epoch 308/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3290
# Epoch 309/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3285
# Epoch 310/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3280
# Epoch 311/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3276
# Epoch 312/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3271
# Epoch 313/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3267
# Epoch 314/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3263
# Epoch 315/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3259
# Epoch 316/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3255
# Epoch 317/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3251
# Epoch 318/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3247
# Epoch 319/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3244
# Epoch 320/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3240
# Epoch 321/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3237
# Epoch 322/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3234
# Epoch 323/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3231
# Epoch 324/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3227
# Epoch 325/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3224
# Epoch 326/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3222
# Epoch 327/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3219
# Epoch 328/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3216
# Epoch 329/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3213
# Epoch 330/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3211
# Epoch 331/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3208
# Epoch 332/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3206
# Epoch 333/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3204
# Epoch 334/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3201
# Epoch 335/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3199
# Epoch 336/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3197
# Epoch 337/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3195
# Epoch 338/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3193
# Epoch 339/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3191
# Epoch 340/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3189
# Epoch 341/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3187
# Epoch 342/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3185
# Epoch 343/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3184
# Epoch 344/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3182
# Epoch 345/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3180
# Epoch 346/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3179
# Epoch 347/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3177
# Epoch 348/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3176
# Epoch 349/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3174
# Epoch 350/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3173
# Epoch 351/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3171
# Epoch 352/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3170
# Epoch 353/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3169
# Epoch 354/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3167
# Epoch 355/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3166
# Epoch 356/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3165
# Epoch 357/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3164
# Epoch 358/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3162
# Epoch 359/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3161
# Epoch 360/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3160
# Epoch 361/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3159
# Epoch 362/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3158
# Epoch 363/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3157
# Epoch 364/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3156
# Epoch 365/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3155
# Epoch 366/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3154
# Epoch 367/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3153
# Epoch 368/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3152
# Epoch 369/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3151
# Epoch 370/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3150
# Epoch 371/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3149
# Epoch 372/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3148
# Epoch 373/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3147
# Epoch 374/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3146
# Epoch 375/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3145
# Epoch 376/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3144
# Epoch 377/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3144
# Epoch 378/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3143
# Epoch 379/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3142
# Epoch 380/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3141
# Epoch 381/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3140
# Epoch 382/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3139
# Epoch 383/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3138
# Epoch 384/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3138
# Epoch 385/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3137
# Epoch 386/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3136
# Epoch 387/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3135
# Epoch 388/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3134
# Epoch 389/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3134
# Epoch 390/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3133
# Epoch 391/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3132
# Epoch 392/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3131
# Epoch 393/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3130
# Epoch 394/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3130
# Epoch 395/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3129
# Epoch 396/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3128
# Epoch 397/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3127
# Epoch 398/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3127
# Epoch 399/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3126
# Epoch 400/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3125
# Epoch 401/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3124
# Epoch 402/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3124
# Epoch 403/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3123
# Epoch 404/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3122
# Epoch 405/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3121
# Epoch 406/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3121
# Epoch 407/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3120
# Epoch 408/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3119
# Epoch 409/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3119
# Epoch 410/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3118
# Epoch 411/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3117
# Epoch 412/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3116
# Epoch 413/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3116
# Epoch 414/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3115
# Epoch 415/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3114
# Epoch 416/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3113
# Epoch 417/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3113
# Epoch 418/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3112
# Epoch 419/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3111
# Epoch 420/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3111
# Epoch 421/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3110
# Epoch 422/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3109
# Epoch 423/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3108
# Epoch 424/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3108
# Epoch 425/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3107
# Epoch 426/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3106
# Epoch 427/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3106
# Epoch 428/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3105
# Epoch 429/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3104
# Epoch 430/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3104
# Epoch 431/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3103
# Epoch 432/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3102
# Epoch 433/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3102
# Epoch 434/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3101
# Epoch 435/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3100
# Epoch 436/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3100
# Epoch 437/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3099
# Epoch 438/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3098
# Epoch 439/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3098
# Epoch 440/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3097
# Epoch 441/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3096
# Epoch 442/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3096
# Epoch 443/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3095
# Epoch 444/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3094
# Epoch 445/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3094
# Epoch 446/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3093
# Epoch 447/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3092
# Epoch 448/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3092
# Epoch 449/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3091
# Epoch 450/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3091
# Epoch 451/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3090
# Epoch 452/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3089
# Epoch 453/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3089
# Epoch 454/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3088
# Epoch 455/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3087
# Epoch 456/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3087
# Epoch 457/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3086
# Epoch 458/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3086
# Epoch 459/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3085
# Epoch 460/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3085
# Epoch 461/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3084
# Epoch 462/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3083
# Epoch 463/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3083
# Epoch 464/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3082
# Epoch 465/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3082
# Epoch 466/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3081
# Epoch 467/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3081
# Epoch 468/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3080
# Epoch 469/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3079
# Epoch 470/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3079
# Epoch 471/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3078
# Epoch 472/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3078
# Epoch 473/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3077
# Epoch 474/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3077
# Epoch 475/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3076
# Epoch 476/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3076
# Epoch 477/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3075
# Epoch 478/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3075
# Epoch 479/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3074
# Epoch 480/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3074
# Epoch 481/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3073
# Epoch 482/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3073
# Epoch 483/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3072
# Epoch 484/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3072
# Epoch 485/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3071
# Epoch 486/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3071
# Epoch 487/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3070
# Epoch 488/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3070
# Epoch 489/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3069
# Epoch 490/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3069
# Epoch 491/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3068
# Epoch 492/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3068
# Epoch 493/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3067
# Epoch 494/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3067
# Epoch 495/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3067
# Epoch 496/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3066
# Epoch 497/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3066
# Epoch 498/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3065
# Epoch 499/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3065
# Epoch 500/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3064

# %% [markdown]
# ### 4. Model Evaluation
#
#
# Model evaluation usually needs both evaluation and testing sets. We only have very few data in this case so we only visualize the changes of loss function during iteration.m

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import matplotlib.pyplot as plt

def plot_metric(history, metric):
    train_metrics = history.history[metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics, 'bo--')
    plt.title('Training '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric])
    plt.show()

# %%
plot_metric(history,"loss")

# %% [markdown]
# ### 5. Model Application
#
#
# We predict the time of the end of COVID-19 here, i.e. the date when the daily increment of new confirmed cases = 0.

# %%
#This "dfresult" is used to record the current and predicted data
dfresult = dfdiff[["confirmed_num","cured_num","dead_num"]].copy()
dfresult.tail()
# Out:
#     confirmed_num  cured_num  dead_num
# 41          143.0     1681.0      30.0
# 42           99.0     1678.0      28.0
# 43           44.0     1661.0      27.0
# 44           40.0     1535.0      22.0
# 45           19.0     1297.0      17.0

# %%
#Predicting the daily increment of the new confirmed cases of the next 100 days; add this result into dfresult
for i in range(100):
    arr_predict = model.predict(tf.constant(tf.expand_dims(dfresult.values[-38:,:],axis = 0)))

    dfpredict = pd.DataFrame(tf.cast(tf.floor(arr_predict),tf.float32).numpy(),
                columns = dfresult.columns)
    dfresult = dfresult.append(dfpredict,ignore_index=True)

# %%
dfresult.query("confirmed_num==0").head()

# From Day 55 the daily increment of the new confirmed cases reduced to zero. Since Day 45 is corresponding to March 10, the daily increment of the news confirmed cases will reduce to 0 in Manch 20.
# Note: this prediction is TOO optimistic
# Out:
#     confirmed_num  cured_num  dead_num
# 49            0.0     1225.0      -0.0
# 50            0.0     1202.0       0.0
# 51            0.0     1178.0      -0.0
# 52            0.0     1153.0       0.0
# 53            0.0     1127.0      -0.0

# %%
dfresult.query("cured_num==0").head()

# The daily increment of the discharged (cured) cases will reduce to 0 in Day 164, which is about 4 months after March 10 (i.e. July 10) all the patients will be discharged.
# Note: this prediction is TOO pessimistic and problematic: the total sum of the daily increment of discharged cases is larger than cumulated confirmed cases.
# Out:
#      confirmed_num  cured_num  dead_num
# 108            0.0        0.0       0.0
# 109            0.0        0.0      -0.0
# 110            0.0        0.0       0.0
# 111            0.0        0.0      -0.0
# 112            0.0        0.0       0.0

# %%
dfresult.query("dead_num==0").head()

# The daily increment of the deceased will be reduced to 0 from Day 60, which is March 25, 2020
# Note: This prediction is relatively reasonable.
# Out:
#     confirmed_num  cured_num  dead_num
# 46            9.0     1282.0       0.0
# 47            4.0     1265.0      -0.0
# 48            1.0     1246.0       0.0
# 49            0.0     1225.0      -0.0
# 50            0.0     1202.0       0.0

# %% [markdown]
# ### 6. Model Saving
#
#
# Model saving with the original way of TensorFlow is recommended.

# %%
model.save('./data/tf_model_savedmodel', save_format="tf")
print('export saved model.')
# Out:
# WARNING:tensorflow:From /Users/alan/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ./data/tf_model_savedmodel/assets
# export saved model.

# %%
model_loaded = tf.keras.models.load_model('./data/tf_model_savedmodel',compile=False)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_loaded.compile(optimizer=optimizer,loss=MSPE(name = "MSPE"))
model_loaded.predict(ds_train)
# Out:
# array([[1924.267   ,   96.848145,   33.18102 ],
#        [2373.4763  ,   75.93775 ,   67.46807 ],
#        [2589.8303  ,  161.78043 ,   63.043934],
#        [2963.8662  ,  172.78589 ,   70.78617 ],
#        [3562.5066  ,  286.14224 ,   71.892204],
#        [3386.4897  ,  287.2428  ,   80.74048 ],
#        [2881.3582  ,  425.9117  ,   80.74048 ],
#        [3103.2126  ,  561.279   ,   95.11892 ],
#        [2431.232   ,  659.2277  ,   98.43702 ],
#        [2725.51    ,  695.5458  ,  107.28529 ],
#        [2261.6323  ,  786.8912  ,  119.45166 ],
#        [1454.1329  ,  804.3946  ,   78.99553 ],
#        [5291.848   , 1184.2847  ,   12.980524],
#        [1405.9879  ,  804.93335 ,    0.      ],
#        [1034.6481  , 1359.6163  ,    0.      ],
#        [ 808.18164 , 1311.7936  ,    0.      ],
#        [ 817.34644 , 1416.191   ,    0.      ],
#        [ 740.13947 , 1702.2753  ,    0.      ],
#        [ 676.3047  , 1822.0417  ,    0.      ],
#        [ 159.68312 , 1772.6322  ,    0.      ],
#        [ 376.54904 , 2101.5405  ,    0.      ],
#        [ 358.47137 , 2384.3638  ,    0.      ],
#        [ 297.12704 , 2204.9653  ,    0.      ],
#        [ 103.59019 , 1810.342   ,    0.      ],
#        [ 259.302   , 2512.7927  ,    0.      ],
#        [ 221.31177 , 2318.9395  ,    0.      ],
#        [ 264.96896 , 2583.239   ,    0.      ],
#        [ 200.10359 , 3402.3606  ,    0.      ],
#        [ 261.29733 , 2710.0527  ,    0.      ],
#        [ 350.64023 , 2463.9404  ,    0.      ],
#        [ 123.61139 , 2664.9634  ,    0.      ],
#        [  76.492195, 2575.724   ,    0.      ],
#        [  72.82057 , 2491.182   ,    0.      ],
#        [  85.059326, 2056.2583  ,    0.      ],
#        [  87.50707 , 1579.0636  ,    0.      ],
#        [  60.58182 , 1576.2455  ,    0.      ],
#        [  26.925257, 1560.2764  ,    0.      ],
#        [  24.477505, 1441.9171  ,    0.      ]], dtype=float32)
